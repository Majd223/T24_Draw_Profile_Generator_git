# %%
# %run T24_Draw_Profile_Generator.py
# Out:
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# total = 19.45540714263916, mixed = 0, hot = 0

# %%
To_Convert = "Building=Multi_Climate=3_Water=Hot_Profile=3a_SDLM=Yes_CFA=600_Included=['F', 'S', 'D'].csv"

# %%
All_Types = To_Convert.replace(".csv","").split(sep = '_')
Specifier_Dict = { each.split(sep = "=")[0] : each.split(sep = "=")[1] for each in All_Types}

# %%
Specifier_Dict['Building']
# Out:
# 'Multi'

# %%
start_laggard_mixed
# Out:
# 0

# %%
Profile = 'DHW' + str(0) + 'BR' + str('a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-9226f8caffb3> in <module>
# ----> 1 Profile = 'DHW' + str(NumberBedrooms_Dwelling) + 'BR' + str(Variant)
#
# NameError: name 'NumberBedrooms_Dwelling' is not defined

# %%
times  = [point_2,point_3, point_4, point_5, point_6, point_7, end]
fraction_times = [each / sum(times) for each in times]
fraction_times
# Out:
# [0.006229813503616754,
#  0.029307984997352692,
#  0.2867553134375883,
#  0.040324859890133624,
#  0.28793796289325485,
#  0.061322210113581244,
#  0.28812185516447253]

# %%
Folder_WeatherData = Folder + os.sep + 'WeatherFiles' #This states the folder that CBECC weather data files are stored in
start_text = 'CTZ0' if len(str(ClimateZone)) == 1 else 'CTZ'  #Identifying the correct file is done differently if the climate zone number is less than 10
File_WeatherData = os.sep + start_text + str(ClimateZone) + 'S13b.CSW' #Create a string stating the location of the weather file. Note the 0 following CTZ in climate zones < 10
Path_WeatherData = Folder_WeatherData + File_WeatherData #Combine Folder and File to create a path stating the location of the weather data

WeatherData = pd.read_csv(Path_WeatherData, header = 26) #Read the weather data, ignoring the first 25 lines of header

First_Hour = WeatherData[WeatherData["Hour"] == 1]
First_Hour = First_Hour.set_index([pd.Index(range(365))])
T_Mains = 0.65 * First_Hour['T Ground'] + 0.35 * First_Hour['31-day Avg lag DB'] #Equation 10, ACM, Appendix B. Returns the mains water temperature as a function of the ground temper

# %%
Daily_Profile['New Col'] = Daily_Profiles['Start Time of Year (hr)'] +4

# %%
Daily_Profile.loc[:,'Mains Temperature (deg F)'] = T_Mains[i]

# %%
Daily_Profile['Mains Temperature (deg F)'] = pd.Series([T_Mains.loc[1]]*len(Daily_Profile))
# Out:
# /Users/nathanieliltis/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
T_Mains[364]
# Out:
# 53.3055

# %%
# %run Convert_Profile_Climate_Zone.py

# %%
Data['Mains Temperature (deg F)'] = Data.apply(lambda x: T_Mains[x['Day of Year (Day)']-1], axis = 1)

# %%
Data
# Out:
#        Day  Day of Year (Day)  Duration (min) Fixture  Flow Rate (gpm)  \
# 0      2H7                1.0           0.427    FAUC         0.127333
# 1      2H7                1.0           0.142    FAUC         1.275547
# 2      2H7                1.0           0.142    FAUC         0.637774
# 3      2H7                1.0           0.427    FAUC         1.509176
# 4      2H7                1.0           0.427    FAUC         0.658811
# 5      2H7                1.0           1.566    FAUC         1.252295
# 6      2H7                1.0           2.278    FAUC         1.215756
# 7      2H7                1.0           0.285    FAUC         0.478330
# 8      2H7                1.0           2.167    DWSH         0.791681
# 9      2H7                1.0           0.427    FAUC         0.998736
# 10     2H7                1.0           0.854    FAUC         1.945431
# 11     2H7                1.0           0.285    FAUC         1.370771
# 12     2H7                1.0           2.167    DWSH         0.785037
# 13     2H7                1.0           0.500    DWSH         0.751820
# 14     2H7                1.0           2.167    DWSH         0.804968
# 15     2H7                1.0           0.285    FAUC         0.573553
# 16     2H7                1.0           0.569    FAUC         1.370771
# 17     2H7                1.0           0.142    FAUC         1.530214
# 18     2H7                1.0           0.142    FAUC         0.510440
# 19     2H7                1.0           0.712    FAUC         1.568968
# 20     2H7                1.0           0.285    FAUC         1.180324
# 21     2H7                1.0           0.427    FAUC         0.765107
# 22     2H7                1.0          10.963    SHWR         2.214492
# 23     2H7                1.0           0.142    FAUC         1.020881
# 24     2H7                1.0           0.427    FAUC         1.275547
# 25     2H7                1.0           0.142    FAUC         0.829327
# 26     2H7                1.0           0.142    FAUC         0.446220
# 27     2H7                1.0           0.142    FAUC         0.383107
# 28     2H7                1.0           0.142    FAUC         0.383107
# 29     2H7                1.0           0.142    FAUC         0.510440
# ...    ...                ...             ...     ...              ...
# 22242  3D8              365.0           0.373    FAUC         1.254510
# 22243  3D8              365.0           0.373    FAUC         1.254510
# 22244  3D8              365.0           0.249    FAUC         0.829327
# 22245  3D8              365.0           0.249    FAUC         2.072765
# 22246  3D8              365.0           0.249    FAUC         1.467101
# 22247  3D8              365.0           0.124    FAUC         0.829327
# 22248  3D8              365.0           0.124    FAUC         0.829327
# 22249  3D8              365.0           0.249    FAUC         1.051884
# 22250  3D8              365.0           0.373    FAUC         1.360805
# 22251  3D8              365.0           0.124    FAUC         1.658655
# 22252  3D8              365.0           1.741    FAUC         1.808133
# 22253  3D8              365.0           2.238    FAUC         0.648846
# 22254  3D8              365.0           0.249    FAUC         0.605664
# 22255  3D8              365.0           0.124    FAUC         1.658655
# 22256  3D8              365.0           0.373    FAUC         1.381843
# 22257  3D8              365.0           1.833    DWSH         1.120533
# 22258  3D8              365.0           1.667    DWSH         1.092852
# 22259  3D8              365.0           0.870    FAUC         0.592377
# 22260  3D8              365.0           1.119    FAUC         1.715124
# 22261  3D8              365.0           0.124    FAUC         1.211327
# 22262  3D8              365.0           0.497    FAUC         1.769379
# 22263  3D8              365.0           0.373    FAUC         0.701994
# 22264  3D8              365.0           1.500    DWSH         1.106139
# 22265  3D8              365.0           0.249    FAUC         1.051884
# 22266  3D8              365.0           0.497    FAUC         1.674156
# 22267  3D8              365.0           0.497    FAUC         0.685385
# 22268  3D8              365.0           0.249    FAUC         1.051884
# 22269  3D8              365.0           0.249    FAUC         1.051884
# 22270  3D8              365.0           0.373    FAUC         0.701994
# 22271  3D8              365.0           0.497    FAUC         0.861437
#
#        Start Time of Year (hr)  Start time (hr)  Mains Temperature (deg F)  \
# 0                         1.54             1.54                    53.3500
# 1                         6.67             6.67                    53.3500
# 2                         6.83             6.83                    53.3500
# 3                         7.60             7.60                    53.3500
# 4                         7.84             7.84                    53.3500
# 5                        11.73            11.73                    53.3500
# 6                        11.78            11.78                    53.3500
# 7                        12.11            12.11                    53.3500
# 8                        12.17            12.17                    53.3500
# 9                        12.22            12.22                    53.3500
# 10                       12.24            12.24                    53.3500
# 11                       12.26            12.26                    53.3500
# 12                       12.34            12.34                    53.3500
# 13                       12.61            12.61                    53.3500
# 14                       12.64            12.64                    53.3500
# 15                       12.87            12.87                    53.3500
# 16                       12.88            12.88                    53.3500
# 17                       12.89            12.89                    53.3500
# 18                       12.97            12.97                    53.3500
# 19                       12.99            12.99                    53.3500
# 20                       13.00            13.00                    53.3500
# 21                       13.03            13.03                    53.3500
# 22                       13.93            13.93                    53.3500
# 23                       14.28            14.28                    53.3500
# 24                       14.33            14.33                    53.3500
# 25                       14.40            14.40                    53.3500
# 26                       14.42            14.42                    53.3500
# 27                       14.64            14.64                    53.3500
# 28                       15.21            15.21                    53.3500
# 29                       15.27            15.27                    53.3500
# ...                        ...              ...                        ...
# 22242                  8754.02            18.02                    53.3055
# 22243                  8754.23            18.23                    53.3055
# 22244                  8754.27            18.27                    53.3055
# 22245                  8754.31            18.31                    53.3055
# 22246                  8754.35            18.35                    53.3055
# 22247                  8754.85            18.85                    53.3055
# 22248                  8754.97            18.97                    53.3055
# 22249                  8755.47            19.47                    53.3055
# 22250                  8755.54            19.54                    53.3055
# 22251                  8755.62            19.62                    53.3055
# 22252                  8756.33            20.33                    53.3055
# 22253                  8756.37            20.37                    53.3055
# 22254                  8756.46            20.46                    53.3055
# 22255                  8756.48            20.48                    53.3055
# 22256                  8756.51            20.51                    53.3055
# 22257                  8757.22            21.22                    53.3055
# 22258                  8757.38            21.38                    53.3055
# 22259                  8757.47            21.47                    53.3055
# 22260                  8757.49            21.49                    53.3055
# 22261                  8757.49            21.49                    53.3055
# 22262                  8757.69            21.69                    53.3055
# 22263                  8757.81            21.81                    53.3055
# 22264                  8757.84            21.84                    53.3055
# 22265                  8758.16            22.16                    53.3055
# 22266                  8758.79            22.79                    53.3055
# 22267                  8758.85            22.85                    53.3055
# 22268                  8758.88            22.88                    53.3055
# 22269                  8758.90            22.90                    53.3055
# 22270                  8758.91            22.91                    53.3055
# 22271                  8758.97            22.97                    53.3055
#
#        Fraction Hot Water  Hot Water Flow Rate (gpm)  Hot Water Volume (gal)
# 0                0.500000                   0.063667                0.027186
# 1                0.500000                   0.637774                0.090564
# 2                0.500000                   0.318887                0.045282
# 3                0.500000                   0.754588                0.322209
# 4                0.500000                   0.329406                0.140656
# 5                0.500000                   0.626148                0.980547
# 6                0.500000                   0.607878                1.384746
# 7                0.500000                   0.239165                0.068162
# 8                1.000000                   0.791681                1.715572
# 9                0.500000                   0.499368                0.213230
# 10               0.500000                   0.972716                0.830699
# 11               0.500000                   0.685385                0.195335
# 12               1.000000                   0.785037                1.701176
# 13               1.000000                   0.751820                0.375910
# 14               1.000000                   0.804968                1.744365
# 15               0.500000                   0.286777                0.081731
# 16               0.500000                   0.685385                0.389984
# 17               0.500000                   0.765107                0.108645
# 18               0.500000                   0.255220                0.036241
# 19               0.500000                   0.784484                0.558552
# 20               0.500000                   0.590162                0.168196
# 21               0.500000                   0.382553                0.163350
# 22               0.837794                   1.855288               20.339524
# 23               0.500000                   0.510440                0.072483
# 24               0.500000                   0.637774                0.272329
# 25               0.500000                   0.414664                0.058882
# 26               0.500000                   0.223110                0.031682
# 27               0.500000                   0.191554                0.027201
# 28               0.500000                   0.191554                0.027201
# 29               0.500000                   0.255220                0.036241
# ...                   ...                        ...                     ...
# 22242            0.500000                   0.627255                0.233966
# 22243            0.500000                   0.627255                0.233966
# 22244            0.500000                   0.414664                0.103251
# 22245            0.500000                   1.036382                0.258059
# 22246            0.500000                   0.733550                0.182654
# 22247            0.500000                   0.414664                0.051418
# 22248            0.500000                   0.414664                0.051418
# 22249            0.500000                   0.525942                0.130960
# 22250            0.500000                   0.680403                0.253790
# 22251            0.500000                   0.829327                0.102837
# 22252            0.500000                   0.904066                1.573980
# 22253            0.500000                   0.324423                0.726059
# 22254            0.500000                   0.302832                0.075405
# 22255            0.500000                   0.829327                0.102837
# 22256            0.500000                   0.690922                0.257714
# 22257            1.000000                   1.120533                2.053937
# 22258            1.000000                   1.092852                1.821784
# 22259            0.500000                   0.296188                0.257684
# 22260            0.500000                   0.857562                0.959612
# 22261            0.500000                   0.605664                0.075102
# 22262            0.500000                   0.884690                0.439691
# 22263            0.500000                   0.350997                0.130922
# 22264            1.000000                   1.106139                1.659208
# 22265            0.500000                   0.525942                0.130960
# 22266            0.500000                   0.837078                0.416028
# 22267            0.500000                   0.342693                0.170318
# 22268            0.500000                   0.525942                0.130960
# 22269            0.500000                   0.525942                0.130960
# 22270            0.500000                   0.350997                0.130922
# 22271            0.500000                   0.430719                0.214067
#
# [22272 rows x 11 columns]
